# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# Imported the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'gardenDB', 'local', 'test', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
db.establishments.find_one()
# Out:
# {'_id': ObjectId('64ac59c86037b8adeafc350c'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}],
#  'latitude': None,
#  'longitude': None}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}
establishments.insert_one(new_restaurant)

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Insert the new restaurant into the collection
# ----> 2 establishments.insert_one(new_restaurant)
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/collection.py:745, in Collection.insert_one(self, document, bypass_document_validation, session)
#     741     document["_id"] = ObjectId()
#     743 write_concern = self._write_concern_for(session)
#     744 return InsertOneResult(
# --> 745     self._insert(
#     746         document,
#     747         write_concern=write_concern,
#     748         bypass_doc_val=bypass_document_validation,
#     749         session=session,
#     750     ),
#     751     write_concern.acknowledged,
#     752 )
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/collection.py:658, in Collection._insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     656 """Internal insert helper."""
#     657 if isinstance(docs, abc.Mapping):
# --> 658     return self._insert_one(
#     659         docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session
#     660     )
#     662 ids = []
#     664 if manipulate:
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/collection.py:640, in Collection._insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     627     result = sock_info.command(
#     628         self.__database.name,
#     629         command,
#    (...)
#     635         retryable_write=retryable_write,
#     636     )
#     638     _check_write_command_response(result)
# --> 640 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     642 if not isinstance(doc, RawBSONDocument):
#     643     return doc.get("_id")
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/mongo_client.py:1644, in MongoClient._retryable_write(self, retryable, func, session)
#    1642 """Internal retryable write helper."""
#    1643 with self._tmp_session(session) as s:
# -> 1644     return self._retry_with_session(retryable, func, s, None)
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/mongo_client.py:1532, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1524 """Execute an operation with at most one consecutive retries
#    1525
#    1526 Returns func()'s return value on success. On error retries the same
#    (...)
#    1529 Re-raises any exception thrown by func().
#    1530 """
#    1531 retryable = retryable and self.options.retry_writes and session and not session.in_transaction
# -> 1532 return self._retry_internal(retryable, func, session, bulk)
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/mongo_client.py:1565, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1563                 raise last_error
#    1564             retryable = False
# -> 1565         return func(session, sock_info, retryable)
#    1566 except ServerSelectionTimeoutError:
#    1567     if is_retrying():
#    1568         # The application may think the write was never attempted
#    1569         # if we raise ServerSelectionTimeoutError on the retry
#    1570         # attempt. Raise the original exception instead.
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/collection.py:638, in Collection._insert_one.<locals>._insert_command(session, sock_info, retryable_write)
#     625     command["bypassDocumentValidation"] = True
#     627 result = sock_info.command(
#     628     self.__database.name,
#     629     command,
#    (...)
#     635     retryable_write=retryable_write,
#     636 )
# --> 638 _check_write_command_response(result)
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/helpers.py:249, in _check_write_command_response(result)
#     247 write_errors = result.get("writeErrors")
#     248 if write_errors:
# --> 249     _raise_last_write_error(write_errors)
#     251 wce = _get_wce_doc(result)
#     252 if wce:
#
# File /Applications/anaconda3/envs/old_notebook/lib/python3.10/site-packages/pymongo/helpers.py:221, in _raise_last_write_error(write_errors)
#     219 error = write_errors[-1]
#     220 if error.get("code") == 11000:
# --> 221     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     222 raise WriteError(error.get("errmsg"), error.get("code"), error)
#
# DuplicateKeyError: E11000 duplicate key error collection: uk_food.establishments index: _id_ dup key: { _id: ObjectId('64ac67c01c57cb405998185a') }, full error: {'index': 0, 'code': 11000, 'errmsg': "E11000 duplicate key error collection: uk_food.establishments index: _id_ dup key: { _id: ObjectId('64ac67c01c57cb405998185a') }", 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('64ac67c01c57cb405998185a')}}

# %%
# Check that the new restaurant was inserted
establishments.find_one(new_restaurant)
# Out:
# {'_id': ObjectId('64ac67c01c57cb405998185a'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {"BusinessType": 'Restaurant/Cafe/Canteen'}
fields = {"BusinessTypeID": 1, 'BusinessType': 1}

results = establishments.find(query, fields)

for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc350c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3518')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc351e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3521')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3524')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3531')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3536')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc353a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc353d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc353f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3541')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3543')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3553')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc355a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc355e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3564')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3565')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3568')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc356c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc356d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3571')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3572')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3573')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3576')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3578')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc357a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc357d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc357e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3583')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3586')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3587')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3588')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc358d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc358e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3598')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3599')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc359c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc359d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35a1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35a7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35ae')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35b2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35ba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35bd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35c2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35c3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35cc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35cd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35d5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35d6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35da')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35df')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35e0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35e1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35ea')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35ec')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35f1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35f6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35f7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35fa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc35fc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3600')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3603')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3605')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3606')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3611')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3613')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3614')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3618')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3619')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc361a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3621')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3623')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3624')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3626')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3629')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc362c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc362e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3633')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3637')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3638')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3643')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc365b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3660')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3662')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc366a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc366c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3687')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3691')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3692')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3694')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3696')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36a4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36a5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36a9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ad')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36b0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36b1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36b8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36c1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36c5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36c6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36c7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36c8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36cb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ce')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36cf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36d0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36d4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36d9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36db')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36e9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ed')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36f4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36f9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36fb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36fd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36fe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc36ff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3702')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc370b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc370f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3714')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3715')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3716')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc371d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc371e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc371f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3723')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3729')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc372f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3739')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc373d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc373e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3743')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3744')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc374a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3752')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3756')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc3758')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc375a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc375b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc375d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('64ac59c86037b8adeafc
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True,
#  'latitude': None,
#  'longitude': None,
#  'RatingValue': None}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}
results = establishments.find(query)
for result in results:
    print(result)

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {'LocalAuthorityName': 'Dover'}
establishments.delete_many(query)
results = establishments.find(query)

# %%
# Check if any remaining documents include Dover
for result in results:
    print(result)

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('64ac59c86037b8adeafc350c'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}],
#  'latitude': None,
#  'longitude': None}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [{'$set' :
                                    {'geocode.latitude':
                                        {'$toDouble': '$geocode.latitude'}
                                    }
                                }
                               ]
                          )
establishments.update_many({}, [{'$set' :
                                    {'geocode.longitude':
                                        {'$toDouble': '$geocode.longitude'}
                                    }
                                }
                               ]
                          )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set' :
                                    {'RatingValue':
                                        {'$toInt': '$RatingValue'}
                                    }
                                }
                               ]
                          )

# %%
# Check that the coordinates and rating value are now numbers
query = {}
fields = {"geocode.longitude" : 1, "geocode.latitude" : 1, "RatingValue" : 1}
list(establishments.find(query,fields))[0:50]
# Out:
# [{'_id': ObjectId('64ac59c86037b8adeafc350c'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.195625, 'latitude': 51.083812}},
#  {'_id': ObjectId('64ac59c86037b8adeafc350e'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.196408, 'latitude': 51.086058}},
#  {'_id': ObjectId('64ac59c86037b8adeafc350f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.194762, 'latitude': 51.085797}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3512'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3513'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3514'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3515'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3516'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3517'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.188537, 'latitude': 51.08084}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3518'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3519'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc351a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc351b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc351d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc351e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc351f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3520'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3521'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3522'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3523'),
#   'RatingValue': 3,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3524'),
#   'RatingValue': 3,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3525'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3526'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3527'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3528'),
#   'RatingValue': 2,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3529'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc352a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc352b'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc352c'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc352e'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc352f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3530'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3531'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3532'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3533'),
#   'RatingValue': 2,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3534'),
#   'RatingValue': 4,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3535'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3536'),
#   'RatingValue': None,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3537'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3538'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3539'),
#   'RatingValue': None,
#   'geocode': {'longitude': 1.18794649942731, 'latitude': 51.0805695006979}},
#  {'_id': ObjectId('64ac59c86037b8adeafc353a'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc353b'),
#   'RatingValue': 3,
#   'geocode': {'longitude': 1.18590330311705, 'latitude': 51.0783519967076}},
#  {'_id': ObjectId('64ac59c86037b8adeafc353d'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.202055, 'latitude': 51.095015}},
#  {'_id': ObjectId('64ac59c86037b8adeafc353e'),
#   'RatingValue': 2,
#   'geocode': {'longitude': 1.18516, 'latitude': 51.078449}},
#  {'_id': ObjectId('64ac59c86037b8adeafc353f'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.187083, 'latitude': 51.080673}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3540'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.186825, 'latitude': 51.080446}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3541'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.186485, 'latitude': 51.080284}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3543'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.186485, 'latitude': 51.080284}},
#  {'_id': ObjectId('64ac59c86037b8adeafc3545'),
#   'RatingValue': 5,
#   'geocode': {'longitude': 1.18628335007084, 'latitude': 51.079985650005}}]
